# %%
pip install gym[classic_control]
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 15.7 MB/s eta 0:00:00
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
# BLACKJACK

import gym

env = gym.make('Blackjack-v1')

nums = 2

for game in range(1, num + 1):
    print(f"\nGame {game}")

    state = env.reset()
    print(f"Initial State: {state}")

    done = False

    while not done:

        action = env.action_space.sample()
        action_name = "H" if action == 1 else "S"

        next_state, reward, done, _ = env.step(action)

        print(f"Action: {action_name}")
        print(f"Next State: {next_state}, Reward: {reward}, Done: {done}")

    if reward > 0:
        print("Result: Player Wins!")
    elif reward < 0:
        print("Result: Dealer Wins!")
    else:
        print("Result: Draw!")
# Out:
# Game 1
# Initial State: (16, 7, False)
# Action: S
# Next State: (16, 7, False), Reward: -1.0, Done: True
# Result: Dealer Wins!
#
# Game 2
# Initial State: (14, 6, False)
# Action: H
# Next State: (21, 6, False), Reward: 0.0, Done: False
# Action: S
# Next State: (21, 6, False), Reward: 1.0, Done: True
# Result: Player Wins!

# %%
import gym

env = gym.make("MountainCar-v0")

num_games = 2

for game in range(1, num_games + 1):
    print(f"\nGame {game}")

    state = env.reset()
    print(f"Initial State: {state}")

    done = False
    total_score = 0

    while not done:

        action = env.action_space.sample()

        if action == 0:
            print("Action: 0 - Push Left")
        elif action == 1:
            print("Action: 1 - Do Nothing")
        elif action == 2:
            print("Action: 2 - Push Right")

        print(action)

        next_state, reward, done, _ = env.step(action)9

        total_score += reward

        print(f"Next State: {next_state}, Reward: {reward}, Done: {done}")

    print(f"Game {game} finished with a total score of {total_score}")
    if done:
        print("Result: Car reached the top!")
    else:
        print("Result: Car failed to reach the top!")
# Out:
# Game 1
# Initial State: [-0.56496996  0.        ]
# Action: 2 - Push Right
# 2
# Next State: [-0.56366044  0.00130949], Reward: -1.0, Done: False
# Action: 0 - Push Left
# 0
# Next State: [-0.5630512   0.00060923], Reward: -1.0, Done: False
# Action: 2 - Push Right
# 2
# Next State: [-0.5611468   0.00190443], Reward: -1.0, Done: False
# Action: 2 - Push Right
# 2
# Next State: [-0.55796134  0.00318545], Reward: -1.0, Done: False
# Action: 0 - Push Left
# 0
# Next State: [-0.5555186   0.00244271], Reward: -1.0, Done: False
# Action: 0 - Push Left
# 0
# Next State: [-0.5538369   0.00168174], Reward: -1.0, Done: False
# Action: 1 - Do Nothing
# 1
# Next State: [-0.5519287   0.00190822], Reward: -1.0, Done: False
# Action: 1 - Do Nothing
# 1
# Next State: [-0.54980826  0.00212044], Reward: -1.0, Done: False
# Action: 2 - Push Right
# 2
# Next State: [-0.54649144  0.0033168 ], Reward: -1.0, Done: False
# Action: 0 - Push Left
# 0
# ...
